# %% [markdown]
# # Данные. Загрузка.
#
# Данные скачать можно [тут](https://drive.google.com/file/d/0BzeJJkS7RDPHa3pIdzUySnpORWs/view?usp=sharing)

# %%
from data_utils.data import Users

# %%
# Загрузим данные
data = Users()

# %% [markdown]
# Возьмём Train выборку

# %%
train = data.get_train()

# %% [markdown]
# Посмотрим на звук

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(train[0][1].T)

# %% [markdown]
# Загрузим модель обучения

# %%
from neural.model import NeuralNetwork

# %%
# Загрузим модель
network = NeuralNetwork()

# %% [markdown]
# Обучим нашу модель

# %%
network.train(train)
# Out:
# [array(0.0)]

# %% [markdown]
# Для каждого слова предскажем его вектор

# %%
vectors = []

for user in data.base.keys():
    for word in data.base[user].keys():
        voice = data[user][word]
        a = voice.copy()
        a.resize(100,20)
        vectors.append(network.predict([[a]])[0][0])

# %% [markdown]
# Попробуем отобразить все вектора

# %%
x = []
y = []

for a in train:
    x.append(a[0])
    y.append(a[1])
